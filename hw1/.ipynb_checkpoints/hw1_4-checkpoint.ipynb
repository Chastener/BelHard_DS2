# %%
import pandas as pd
import numpy as np

# Загрузка данных
data = pd.read_csv('auto-mpg.csv')
print(data.head())
print(data.size)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
# 3582

# %%
#Проверка пропусков в данных
print(len(data))
print(data.isnull().sum())
print(data.isin(['?']).any())
data.drop(data[data['horsepower'] == "?"].index, inplace = True)
print(data.isin(['?']).any())
print(len(data))
# Out:
# 398
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64
# mpg             False
# cylinders       False
# displacement    False
# horsepower       True
# weight          False
# acceleration    False
# model year      False
# origin          False
# car name        False
# dtype: bool
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model year      False
# origin          False
# car name        False
# dtype: bool
# 392

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

y = data.iloc[:, 0]
#car name уникальный, поэтому не участвует в предсказаниях
X = data.iloc[:, 1:-1]

# Разделение данных на обучающий и тестовый наборы
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

plt.figure(figsize=(15, 10))
sns.boxplot(data=X_train)
plt.title('Boxplot до нормализации')
plt.show()
# Нормализация признаков
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

plt.figure(figsize=(15, 10))
sns.boxplot(data=X_train)
plt.title('Boxplot после нормализации')
plt.show()

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# Обучение модели регрессии (SVR)
model = SVR(kernel='linear', C=1)
model.fit(X_train, y_train)

# Предсказание на тестовом наборе
y_pred = model.predict(X_test)

# Метрики качества
msa = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error (MSE):", msa)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R2):", r2)

# Визуализация результатов (пример)
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("Реальные значения")
plt.ylabel("Предсказанные значения")
plt.title("Сравнение реальных и предсказанных значений")
plt.show()

# Визуализация распределения ошибок
errors = y_test - y_pred

plt.figure(figsize=(8,6))
sns.histplot(errors, bins=50, kde=True)
plt.xlabel('Ошибка предсказания')
plt.title('Распределение ошибок предсказания')
plt.show()
# Out:
# Mean Absolute Error (MSE): 2.9755755318950947
# Mean Squared Error (MSE): 19.425834080056624
# R-squared (R2): 0.7240880542837171

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

gbr = RandomForestRegressor(random_state=15)
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 3]
}
grid_search = GridSearchCV(
    estimator=gbr,
    param_grid=param_grid,
    cv=5,
    n_jobs=-1,
    scoring='neg_mean_squared_error',
    verbose=2
)
grid_search.fit(X_train, y_train)
print("Лучшие параметры:", grid_search.best_params_)

best_gbr = grid_search.best_estimator_
y_pred = best_gbr.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"R^2 Score: {r2:.4f}")

plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('Фактические значения')
plt.ylabel('Предсказанные значения')
plt.title('Фактические vs Предсказанные значения')
plt.show()

errors = y_test - y_pred

plt.figure(figsize=(8,6))
sns.histplot(errors, bins=50, kde=True)
plt.xlabel('Ошибка предсказания')
plt.title('Распределение ошибок предсказания')
plt.show()

feature_importances = best_gbr.feature_importances_
features = X.columns

importance_df = pd.DataFrame({
    'Признак': features,
    'Важность': feature_importances
}).sort_values(by='Важность', ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x='Важность', y='Признак', data=importance_df)
plt.title('Важность признаков')
plt.xlabel('Важность')
plt.ylabel('Признаки')
plt.show()
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\Msi Bravo\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Лучшие параметры: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Mean Absolute Error (MAE): 2.5847
# Mean Squared Error (MSE): 15.1183
# R^2 Score: 0.7853

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

gbr = XGBRegressor(random_state=15)
param_grid = {
    'num_parallel_tree': [100, 200, 300],
    'learning_rate': [0.05, 0.1],
    'max_depth': [3, 5, 7]
}
grid_search = GridSearchCV(
    estimator=gbr,
    param_grid=param_grid,
    cv=5,
    n_jobs=-1,
    scoring='neg_mean_squared_error',
    verbose=2
)
grid_search.fit(X_train, y_train)
print("Лучшие параметры:", grid_search.best_params_)

best_gbr = grid_search.best_estimator_
y_pred = best_gbr.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"R^2 Score: {r2:.4f}")

plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('Фактические значения')
plt.ylabel('Предсказанные значения')
plt.title('Фактические vs Предсказанные значения')
plt.show()

errors = y_test - y_pred

plt.figure(figsize=(8,6))
sns.histplot(errors, bins=50, kde=True)
plt.xlabel('Ошибка предсказания')
plt.title('Распределение ошибок предсказания')
plt.show()

feature_importances = best_gbr.feature_importances_
features = X.columns

importance_df = pd.DataFrame({
    'Признак': features,
    'Важность': feature_importances
}).sort_values(by='Важность', ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x='Важность', y='Признак', data=importance_df)
plt.title('Важность признаков')
plt.xlabel('Важность')
plt.ylabel('Признаки')
plt.show()
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\Users\Msi Bravo\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Лучшие параметры: {'learning_rate': 0.1, 'max_depth': 3, 'num_parallel_tree': 200}
# Mean Absolute Error (MAE): 2.5174
# Mean Squared Error (MSE): 13.9083
# R^2 Score: 0.8025

# %%
from sklearn.preprocessing import LabelEncoder
data = pd.read_csv('auto-mpg.csv')
data.drop(data[data['horsepower'] == "?"].index, inplace = True)
data['car name'] = data['car name'].str.split(' ').str[0]

enc = LabelEncoder()
data['car name'] = enc.fit_transform(data[['car name']])

y = data.iloc[:, 0]
X = data.iloc[:, 1:]

plt.figure(figsize=(10, 8))
sns.heatmap(X.corr(), annot=True, cmap='coolwarm')
plt.title('Матрица корреляции')
plt.show()
# Out:
# C:\Users\Msi Bravo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Разделение данных на обучающий и тестовый наборы
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

# Нормализация признаков
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

gbr = XGBRegressor(random_state=15, learning_rate=0.1, max_depth=3, num_parallel_tree=200,)
gbr.fit(X_train, y_train)
y_pred = gbr.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"R^2 Score: {r2:.4f}")

plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('Фактические значения')
plt.ylabel('Предсказанные значения')
plt.title('Фактические vs Предсказанные значения')
plt.show()

errors = y_test - y_pred

plt.figure(figsize=(8,6))
sns.histplot(errors, bins=50, kde=True)
plt.xlabel('Ошибка предсказания')
plt.title('Распределение ошибок предсказания')
plt.show()

feature_importances = gbr.feature_importances_
features = X.columns

importance_df = pd.DataFrame({
    'Признак': features,
    'Важность': feature_importances
}).sort_values(by='Важность', ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x='Важность', y='Признак', data=importance_df)
plt.title('Важность признаков')
plt.xlabel('Важность')
plt.ylabel('Признаки')
plt.show()
# Out:
# Mean Absolute Error (MAE): 2.4359
# Mean Squared Error (MSE): 13.1872
# R^2 Score: 0.8127

# %%
from sklearn.preprocessing import LabelEncoder
data = pd.read_csv('auto-mpg.csv')
data.drop(data[data['horsepower'] == "?"].index, inplace = True)
data['car name'] = data['car name'].str.split(' ').str[0]

enc = LabelEncoder()
data['car name'] = enc.fit_transform(data[['car name']])
data = data.drop(columns=["cylinders"])
y = data.iloc[:, 0]
X = data.iloc[:, 1:]

plt.figure(figsize=(10, 8))
sns.heatmap(X.corr(), annot=True, cmap='coolwarm')
plt.title('Матрица корреляции')
plt.show()
# Out:
# C:\Users\Msi Bravo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Разделение данных на обучающий и тестовый наборы
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

# Нормализация признаков
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

gbr = XGBRegressor(random_state=15, learning_rate=0.1, max_depth=3, num_parallel_tree=200,)
gbr.fit(X_train, y_train)
y_pred = gbr.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"R^2 Score: {r2:.4f}")

plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('Фактические значения')
plt.ylabel('Предсказанные значения')
plt.title('Фактические vs Предсказанные значения')
plt.show()

errors = y_test - y_pred

plt.figure(figsize=(8,6))
sns.histplot(errors, bins=50, kde=True)
plt.xlabel('Ошибка предсказания')
plt.title('Распределение ошибок предсказания')
plt.show()

feature_importances = gbr.feature_importances_
features = X.columns

importance_df = pd.DataFrame({
    'Признак': features,
    'Важность': feature_importances
}).sort_values(by='Важность', ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x='Важность', y='Признак', data=importance_df)
plt.title('Важность признаков')
plt.xlabel('Важность')
plt.ylabel('Признаки')
plt.show()
# Out:
# Mean Absolute Error (MAE): 2.4616
# Mean Squared Error (MSE): 13.3372
# R^2 Score: 0.8106
